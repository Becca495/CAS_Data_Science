# %% [markdown]
# #University of Bern: Module 3 Neural Network Project

# %% [markdown]
# ## 4. CNN - Convolutional Neural Network / 3

# %% [markdown]
# ###Importing the libraries:

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import cv2
import os
import PIL
import tensorflow as tf
from tqdm import tqdm

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

from sklearn.model_selection import train_test_split

# %% [markdown]
# ###Download of the data from GitHub repository:

# %%
# create a directory
#!mkdir brain_tumor_dataset
#!cd brain_tumor_dataset

# download the dataset
# !wget https://github.com/SartajBhuvaji/Brain-Tumor-Classification-DataSet/archive/master.zip

# unzip the dataset and delete the zip
# !unzip master.zip && rm master.zip

# concatenate the multiple zipped data in a single zip
#cat brainTumorDataPublic_* > brainTumorDataPublic_temp.zip
#zip -FF brainTumorDataPublic_temp.zip --out data.zip

# remove the temporary files
#rm brainTumorDataPublic_*

# unzip the full archive and delete it 
#unzip data.zip -d data && rm data.zip
# Out:
# --2021-03-07 16:35:20--  https://github.com/SartajBhuvaji/Brain-Tumor-Classification-DataSet/archive/master.zip
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/SartajBhuvaji/Brain-Tumor-Classification-DataSet/zip/master [following]
# --2021-03-07 16:35:21--  https://codeload.github.com/SartajBhuvaji/Brain-Tumor-Classification-DataSet/zip/master
# Resolving codeload.github.com (codeload.github.com)... 140.82.112.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.112.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘master.zip’
#
# master.zip              [                 <=>]  86.97M  26.6MB/s    in 3.3s
#
# 2021-03-07 16:35:24 (26.3 MB/s) - ‘master.zip’ saved [91198591]
#
# Archive:  master.zip
# 3ea9f4eae54c67e5bddbf6f7a73582967a5f5f79
#    creating: Brain-Tumor-Classification-DataSet-master/
#    creating: Brain-Tumor-Classification-DataSet-master/Testing/
#    creating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(1).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(10).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(100).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(11).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(12).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(13).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(14).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(15).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(16).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(17).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(18).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(19).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(2).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(20).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(21).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(22).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(23).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(24).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(25).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(26).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(27).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(28).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(29).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(3).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(30).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(31).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(32).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(33).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(34).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(35).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(36).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(37).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(38).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(39).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(4).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(40).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(41).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(42).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(43).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(44).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(45).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(46).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(47).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(48).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(49).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(5).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(50).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(51).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(52).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(53).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor/image(54).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Testing
jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (154).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (155).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (156).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (157).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (158).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (159).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (16).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (160).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (161).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (162).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (163).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (164).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (165).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (166).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (167).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (168).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (169).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (17).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (170).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (171).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (172).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (173).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (174).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (175).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (176).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (177).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (178).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (179).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (18).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (180).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (181).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (182).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (183).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (184).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (185).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (186).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (187).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (188).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (189).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (19).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (190).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (191).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (192).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (193).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (194).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (195).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor/gg (196).jpg
# ...
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (691).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (692).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (693).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (694).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (695).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (696).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (697).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (698).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (699).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (7).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (70).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (700).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (701).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (702).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (703).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (704).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (705).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (706).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (707).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (708).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (709).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (71).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (710).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (711).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (712).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (713).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (714).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (715).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (716).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (717).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (718).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (719).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (72).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (720).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (721).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (722).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (723).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (724).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (725).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (726).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (727).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (728).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (729).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (73).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (730).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (731).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (732).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (733).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (734).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (735).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (736).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (737).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (738).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (739).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (74).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (740).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (741).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (742).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (743).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (744).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (745).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (746).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (747).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (748).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (749).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (75).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (750).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (751).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (752).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (753).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (754).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (755).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (756).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (757).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (758).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (759).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (76).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (760).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (761).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (762).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (763).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (764).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (765).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (766).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (767).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (768).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (769).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (77).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (770).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (771).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (772).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (773).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (774).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (775).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (776).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (777).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (778).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (779).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (78).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (780).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (781).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (782).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (783).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (784).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (785).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (786).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (787).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (788).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (789).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (79).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (790).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (791).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (792).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (793).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (794).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (795).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (796).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (797).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (798).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (799).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (8).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (80).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (800).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (801).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (802).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (803).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (804).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (805).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (806).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (807).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (808).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (809).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (81).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (810).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (811).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (812).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (813).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (814).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (815).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (816).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (817).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (818).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (819).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (82).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (820).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (821).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (822).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (823).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (824).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (825).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (826).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (827).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (83).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (84).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (85).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (86).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (87).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (88).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (89).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (9).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (90).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (91).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (92).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (93).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (94).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (95).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (96).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (97).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (98).jpg
#   inflating: Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor/p (99).jpg

# %%
# check that "master" contains 3264 files
# !find /content/Brain-Tumor-Classification-DataSet-master -type f | wc -l
# Out:
# 3264

# %% [markdown]
# ### Setting up images parameters:

# %%
img_height = 224
img_width = 224
convert_to_grayscale = True

# %% [markdown]
# ### Feeding Training and Test data into list and arrays:

# %%
#Feeding Training Data to X_train and y_train

train_dir = "/content/Brain-Tumor-Classification-DataSet-master/Training"
test_dir = "/content/Brain-Tumor-Classification-DataSet-master/Testing"
train_glioma = "/content/Brain-Tumor-Classification-DataSet-master/Training/glioma_tumor"
train_meningioma = "/content/Brain-Tumor-Classification-DataSet-master/Training/meningioma_tumor"
train_no_tumour = "/content/Brain-Tumor-Classification-DataSet-master/Training/no_tumor"
train_pituitary = "/content/Brain-Tumor-Classification-DataSet-master/Training/pituitary_tumor"

X_train = []
y_train = []

for i in tqdm(os.listdir(train_glioma)):
    path = os.path.join(train_glioma,i)
    img = cv2.imread(path)
    img = cv2.resize(img,(img_height,img_width))
    if convert_to_grayscale:   
      img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)          # convert to grayscale
    X_train.append(img)
    y_train.append('Glioma')
    
for i in tqdm(os.listdir(train_meningioma)):
    path = os.path.join(train_meningioma,i)
    img = cv2.imread(path)
    img = cv2.resize(img,(img_height,img_width))
    if convert_to_grayscale:   
      img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)          # convert to grayscale
    X_train.append(img)
    y_train.append('Meningioma')
    
for i in tqdm(os.listdir(train_no_tumour)):
    path = os.path.join(train_no_tumour,i)
    img = cv2.imread(path)
    img = cv2.resize(img,(img_height,img_width))
    if convert_to_grayscale:   
      img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)          # convert to grayscale
    X_train.append(img)
    y_train.append('No_Tumour')   
    
for i in tqdm(os.listdir(train_pituitary)):
    path = os.path.join(train_pituitary,i)
    img = cv2.imread(path)
    img = cv2.resize(img,(img_height,img_width))
    if convert_to_grayscale:   
      img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)          # convert to grayscale
    X_train.append(img)
    y_train.append('Pituitary')
# Out:
# 100%|██████████| 826/826 [00:02<00:00, 302.75it/s]
# 100%|██████████| 822/822 [00:02<00:00, 329.09it/s]
# 100%|██████████| 395/395 [00:00<00:00, 423.85it/s]
# 100%|██████████| 827/827 [00:02<00:00, 291.43it/s]

# %%
#Feeding Testing Data to X_train and y_train

train_dir = "/content/Brain-Tumor-Classification-DataSet-master/Training"
test_dir = "/content/Brain-Tumor-Classification-DataSet-master/Testing"
test_glioma = "/content/Brain-Tumor-Classification-DataSet-master/Testing/glioma_tumor"
test_meningioma = "/content/Brain-Tumor-Classification-DataSet-master/Testing/meningioma_tumor"
test_no_tumour = "/content/Brain-Tumor-Classification-DataSet-master/Testing/no_tumor"
test_pituitary = "/content/Brain-Tumor-Classification-DataSet-master/Testing/pituitary_tumor"

X_test = []
y_test = []

for i in tqdm(os.listdir(test_glioma)):
    path = os.path.join(test_glioma,i)
    img = cv2.imread(path)
    img = cv2.resize(img,(img_height,img_width))
    if convert_to_grayscale:   
      img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)          # convert to grayscale
    X_test.append(img)
    y_test.append('Glioma')
    
for i in tqdm(os.listdir(test_meningioma)):
    path = os.path.join(test_meningioma,i)
    img = cv2.imread(path)
    img = cv2.resize(img,(img_height,img_width))
    if convert_to_grayscale:   
      img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)          # convert to grayscale
    X_test.append(img)
    y_test.append('Meningioma')
    

for i in tqdm(os.listdir(test_no_tumour)):
    path = os.path.join(test_no_tumour,i)
    img = cv2.imread(path)
    img = cv2.resize(img,(img_height,img_width))
    if convert_to_grayscale:   
      img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)          # convert to grayscale
    X_test.append(img)
    y_test.append('No_Tumour') 
    
for i in tqdm(os.listdir(test_pituitary)):
    path = os.path.join(test_pituitary,i)
    img = cv2.imread(path)
    img = cv2.resize(img,(img_height,img_width))
    if convert_to_grayscale:   
      img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)          # convert to grayscale
    X_test.append(img)
    y_test.append('Pituitary')
# Out:
# 100%|██████████| 100/100 [00:00<00:00, 362.52it/s]
# 100%|██████████| 115/115 [00:00<00:00, 489.56it/s]
# 100%|██████████| 105/105 [00:00<00:00, 854.74it/s]
# 100%|██████████| 74/74 [00:00<00:00, 161.97it/s]

# %%
X_train = np.array(X_train)
y_train = np.array(y_train)
X_train.shape,y_train.shape
# Out:
# ((2870, 224, 224), (2870,))

# %%
X_test = np.array(X_test)
y_test = np.array(y_test)
X_test.shape,y_test.shape
# Out:
# ((394, 224, 224), (394,))

# %% [markdown]
# ### Normalization of images:

# %%
X_train = X_train/255.0
X_test = X_test/255.0
if convert_to_grayscale:
    X_train = X_train.reshape(-1, img_height, img_width, 1)
    X_test = X_test.reshape(-1, img_height, img_width, 1)

print ('train: data shape', X_train.shape, 'label shape', y_train.shape)
print ('test: data shape', X_test.shape, 'label shape', y_test.shape)
# Out:
# train: data shape (2870, 224, 224, 1) label shape (2870,)
# test: data shape (394, 224, 224, 1) label shape (394,)

# %% [markdown]
# ### Labels encoding and categorisation:

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()
y_train = LE.fit_transform(y_train)

# %%
unique,counts = np.unique(y_train,return_counts=True)
print(unique,counts)
# Out:
# [0 1 2 3] [826 822 395 827]

# %%
y_train

# %%
y_train = to_categorical(y_train)  #num_classes = 4
y_train.shape
# Out:
# (2870, 4)

# %%
y_train

# %%
y_test

# %%
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y_test = le.fit_transform(y_test)

# %%
y_test

# %%
unique1,counts1 = np.unique(y_test,return_counts=True)
print(unique1,counts1)
# Out:
# [0 1 2 3] [100 115 105  74]

# %%
y_test = to_categorical(y_test)#num_classes = 4
y_test.shape
# Out:
# (394, 4)

# %%
y_test

# %% [markdown]
# ### Training, Validation and Test dataset split:

# %%
#X_train , X_test, y_train, y_test = train_test_split(X , y_enc , test_size = 0.1, random_state = 42)
X_train , X_val, y_train, y_val = train_test_split(X_train , y_train , test_size = 0.1, random_state = 42)

# %% [markdown]
# ### CNN model building:

# %%
#from sklearn.metrics import confusion_matrix
#import itertools

from keras.utils.np_utils import to_categorical 
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras.optimizers import RMSprop,Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from keras.callbacks import EarlyStopping

ch = 3
if convert_to_grayscale:
  ch = 1

model = Sequential()

#tf.keras.layers.Flatten(input_shape=(128, 128,3))
model.add(Conv2D(filters = 64, kernel_size = (5,5),padding = 'Same', activation ='relu', input_shape=(img_height,img_width,ch))) #, input_shape = (224,224,3)))
model.add(MaxPool2D(pool_size=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(filters = 128, kernel_size = (3,3),padding = 'Same', activation ='relu'))  # Softmax
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(filters = 128, kernel_size = (3,3),padding = 'Same', activation ='relu'))   #Softmax
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(filters = 128, kernel_size = (2,2),padding = 'Same', activation ='relu'))    #Softmax
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.2))

model.add(Conv2D(filters = 256, kernel_size = (2,2),padding = 'Same', activation ='relu'))    #Softmax
model.add(MaxPool2D(pool_size=(2,2), strides=(2,2)))
model.add(Dropout(0.2))

model.add(Flatten())

model.add(Dense(1024, activation = "relu"))
model.add(Dropout(0.5))

model.add(Dense(4, activation = "softmax"))

optimizer = tf.keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999)
            # SGD(learning_rate=0.001, momentum=0.0, nesterov=True, name='SGD')
            # Nadam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-07,name='Nadam')
            # RMSprop(learning_rate=0.001, rho=0.9, momentum=0.0, epsilon=1e-07, centered=False, name='RMSprop')

model.compile(optimizer = optimizer , loss = "categorical_crossentropy", metrics=["accuracy"])

epochs = 35

es = EarlyStopping( 
    monitor='val_acc', 
    mode='max',
    patience = 3
)

batch_size = 16

imggen = ImageDataGenerator( 
        featurewise_center=False,  
        samplewise_center=False, 
        featurewise_std_normalization=False,  
        samplewise_std_normalization=False,  
        zca_whitening=False,  
        rotation_range=0,   ## 40
        zoom_range = 0,     ## 0.2
        width_shift_range=0,  ## 0.2
        height_shift_range=0,  ## 0.2
        ##shear_range=0.2,        ## not set up previously
        horizontal_flip=True,  
        vertical_flip=False)

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 224, 224, 64)      1664
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 112, 112, 64)      0
# _________________________________________________________________
# dropout (Dropout)            (None, 112, 112, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 112, 112, 128)     73856
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 56, 56, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 56, 56, 128)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 56, 56, 128)       147584
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 28, 28, 128)       65664
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 14, 14, 256)       131328
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 7, 7, 256)         0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 7, 7, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 12544)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              12846080
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 4100
# =================================================================
# Total params: 13,270,276
# Trainable params: 13,270,276
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Model training:

# %%
imggen.fit(X_train)

history = model.fit(imggen.flow(X_train,y_train,batch_size = batch_size, shuffle=True),
                                epochs = epochs, validation_data = (X_val,y_val),
                              steps_per_epoch = len(X_train) // batch_size,
                               callbacks = [es])
# Out:
# Epoch 1/35
# 161/161 [==============================] - 45s 74ms/step - loss: 1.1995 - accuracy: 0.4529 - val_loss: 0.7161 - val_accuracy: 0.7073
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 2/35
# 161/161 [==============================] - 9s 56ms/step - loss: 0.7970 - accuracy: 0.6496 - val_loss: 0.6123 - val_accuracy: 0.7178
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 3/35
# 161/161 [==============================] - 9s 56ms/step - loss: 0.6440 - accuracy: 0.7270 - val_loss: 0.5493 - val_accuracy: 0.7944
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 4/35
# 161/161 [==============================] - 9s 56ms/step - loss: 0.5480 - accuracy: 0.7779 - val_loss: 0.3822 - val_accuracy: 0.8571
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 5/35
# 161/161 [==============================] - 9s 56ms/step - loss: 0.4421 - accuracy: 0.8316 - val_loss: 0.3965 - val_accuracy: 0.8293
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 6/35
# 161/161 [==============================] - 9s 56ms/step - loss: 0.4179 - accuracy: 0.8231 - val_loss: 0.3614 - val_accuracy: 0.8676
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 7/35
# 161/161 [==============================] - 9s 56ms/step - loss: 0.3448 - accuracy: 0.8528 - val_loss: 0.4861 - val_accuracy: 0.8258
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 8/35
# 161/161 [==============================] - 9s 57ms/step - loss: 0.3317 - accuracy: 0.8804 - val_loss: 0.4051 - val_accuracy: 0.8362
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 9/35
# 161/161 [==============================] - 9s 57ms/step - loss: 0.2832 - accuracy: 0.8893 - val_loss: 0.3106 - val_accuracy: 0.8780
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 10/35
# 161/161 [==============================] - 9s 56ms/step - loss: 0.2309 - accuracy: 0.9191 - val_loss: 0.2718 - val_accuracy: 0.9024
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 11/35
# 161/161 [==============================] - 9s 57ms/step - loss: 0.2474 - accuracy: 0.9076 - val_loss: 0.2649 - val_accuracy: 0.8990
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 12/35
# 161/161 [==============================] - 9s 56ms/step - loss: 0.2121 - accuracy: 0.9085 - val_loss: 0.2865 - val_accuracy: 0.8885
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 13/35
# 161/161 [==============================] - 9s 57ms/step - loss: 0.2100 - accuracy: 0.9197 - val_loss: 0.2901 - val_accuracy: 0.9129
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 14/35
# 161/161 [==============================] - 9s 57ms/step - loss: 0.1889 - accuracy: 0.9238 - val_loss: 0.2484 - val_accuracy: 0.9268
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch 15/35
# 161/161 [==============================] - 9s 57ms/step - loss: 0.1892 - accuracy: 0.9260 - val_loss: 0.2326 - val_accuracy: 0.9233
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# Epoch
# WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy

# %% [markdown]
# ## Evaluation of the model:

# %%
fig, axs = plt.subplots(1, 2, figsize=(15,7))
axs[0].plot(history.epoch, history.history['loss'], c = "red", linestyle='dashed')
axs[0].plot(history.epoch, history.history['val_loss'], c = "blue")
axs[0].legend(('training loss', 'validation loss'))#, loc='lower right')
axs[0].set_title("Loss")
axs[0].set_xlabel("Epochs")
axs[0].set_ylabel("Loss")
axs[1].plot(history.epoch, history.history['accuracy'], c = "red", linestyle='dashed')
axs[1].plot(history.epoch, history.history['val_accuracy'], c = "blue")
axs[1].legend(('training accuracy', 'validation accuracy'), loc='lower right')
axs[1].set_title("Accuracy")
axs[1].set_xlabel("Epochs")
axs[1].set_ylabel("Accuracy")
plt.show()

# %% [markdown]
# ## Predictions

# %%
y_pred= model.predict(X_test)
y_pred = np.argmax(y_pred,axis=1)
y_pred[:15]
# Out:
# array([0, 2, 1, 2, 1, 1, 1, 2, 1, 2, 2, 1, 2, 2, 0])

# %%
unique,counts = np.unique(y_pred,return_counts=True)
print(unique,counts)
# Out:
# [0 1 2 3] [ 26 154 155  59]

# %%
model.evaluate(X_test, y_test, verbose=1)
# Out:
# 13/13 [==============================] - 1s 37ms/step - loss: 3.6546 - accuracy: 0.7335
# [3.654602289199829, 0.7335025668144226]

# %% [markdown]
# ## Classification report

# %%
y_test_new = np.argmax(y_test,axis=1)

# %%
y_test_new.shape
# Out:
# (394,)

# %%
from sklearn.metrics import classification_report

clf_report = classification_report(y_test_new, y_pred, labels=[0, 1, 2, 3], target_names=['Glioma','Meningioma','No tumor','Pituitary'])
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#       Glioma       0.88      0.23      0.37       100
#   Meningioma       0.69      0.92      0.79       115
#     No tumor       0.67      0.99      0.80       105
#    Pituitary       0.95      0.76      0.84        74
#
#     accuracy                           0.73       394
#    macro avg       0.80      0.72      0.70       394
# weighted avg       0.78      0.73      0.69       394

# %% [markdown]
# Remainder:
# - precision (p): true positive / (true positive + false positive)
# - recall (r): true positive / (true positive + false negative)
# - F1-score: harmonic mean combining p and r = 2 / (1/p + 1/r)

# %% [markdown]
# ## Model Testing

# %%
plt.figure(figsize=(12,9))
for i in range(10):
    sample_idx = np.random.choice(range(len(X_test)))
    plt.subplot(2,5,i+1)
    plt.imshow(X_test.reshape(-1, img_height, img_width)[sample_idx], cmap='gray', interpolation='nearest')
    plt.xlabel(f"Actual: {y_test_new[sample_idx]}\n Predicted: {y_pred[sample_idx]}")
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Confusion Matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test_new,y_pred)

plt.figure(figsize=(12,9))
ax= plt.subplot()
##group_names = [‘True Neg’,’False Pos’,’False Neg’,’True Pos’]
group_counts = ['{0:0.0f}'.format(value) for value in
                cm.flatten()]
group_percentages = ['{0:.2%}'.format(value) for value in
                     cm.flatten()/np.sum(cm)]
labels = [f'{v1}\n{v2}' for v1, v2 in  #   \n{v3}     v3
          zip(group_counts,group_percentages)]   # group_names,
labels = np.asarray(labels).reshape(4,4)
sns.heatmap(cm, annot=labels, fmt='', cmap='Blues', center=50)

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(['Glioma', 'Meningioma', 'No tumor', 'Pituitary'])
ax.yaxis.set_ticklabels(['Glioma', 'Meningioma', 'No tumor', 'Pituitary']);

#sns.heatmap(cm, annot=True, , ax = ax, cmap='Blues', center=50, fmt='g' ); #annot=True to annotate cells
